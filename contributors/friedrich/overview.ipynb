# %%
# %load_ext autoreload
# %autoreload 2

# %%
import cntp
import tools

from pathlib import Path
import numpy as np

# %%
base_dir = Path("/Users/knuth/Documents/software/CNTP_hackathon/contributors/friedrich/")

# %%
ref_cloud_path = base_dir / "DenseCloud_TL_Arg_2023_09_27_1300_wPGCPs_TLCAM_autom.txt"
tba_cloud_dir = base_dir / "Coreg_avec_photoTL_27-09/"

# OUTPUT DIRECTORIES
dem_dir = base_dir / "dem_dir/"
PC_dir = str(base_dir / "PC_dir/")
plot_dir = base_dir / "plot_dir"

# BBOX
min_bound = np.array([1.0106e6, 6.5445e6, 2750])
max_bound = np.array([1.0112e6, 6.5452e6, 3300])

# %%
cntp.batch.coreg_pc(ref_cloud_path, 
             tba_cloud_dir, 
             dem_dir, 
             PC_dir,
             plot_dir,
             min_bound,
             max_bound,
             crs_epsg = "EPSG:2154",
             overwrite=True,
             overwrite_plots=False
             )
# Out:
# Skipping plot (already exists): /Users/knuth/Documents/software/CNTP_hackathon/contributors/friedrich/plot_dir/stable_terrain_geometry.png
# Skipping plot (already exists): /Users/knuth/Documents/software/CNTP_hackathon/contributors/friedrich/plot_dir/ndwi_vs_intensity.png
# Skipping plot (already exists): /Users/knuth/Documents/software/CNTP_hackathon/contributors/friedrich/plot_dir/stable_terrain_ref_rgb.png
# Co-registering point clouds:   0%|          | 0/4 [00:00<?, ?it/s]
# Processing PC_TL2023-03-04_100002_coreg_TL
# Skipping plot (already exists): /Users/knuth/Documents/software/CNTP_hackathon/contributors/friedrich/plot_dir/stable_terrain_PC_TL2023-03-04_100002_coreg_TL_rgb.png
# [2026-04-02 16:56:34][INFO] Building KDTree structure with leaf parameter 10
# [2026-04-02 16:56:34][INFO] Building KDTree structure with leaf parameter 10
# Median M3C2 distances STABLE: -0.189 m
# Std. dev. of M3C2 distances STABLE: 2.287 m
# ...
