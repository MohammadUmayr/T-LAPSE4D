# %%
# %load_ext autoreload
# %autoreload 2

# %%
import cntp
import tools

from pathlib import Path
import numpy as np

# %%
base_dir = Path("/home/asus/software/CNTP_hackathon/contributors/umayr")

# %%
ref_cloud_path = base_dir / "UAV.laz"
tba_cloud_dir = base_dir / "tba"
output_dir = base_dir / "output"

# %%
cntp.batch.coreg_pc(
    ref_cloud_path,
    tba_cloud_dir,
    output_dir,
    crs_epsg="EPSG:4326",
    downsample_factor= 0.15,
    overwrite=True,
    overwrite_plots=True)
# Out:
# Bounds from reference header: min=[  86.7703259   27.975474  5312.04     ], max=[  86.781583    27.9846204 5745.71     ]
# Co-registering point clouds:   0%|          | 0/3 [00:00<?, ?it/s]
# Processing Reference_UAV_TLC
# [2026-04-21 16:36:29][INFO] Building KDTree structure with leaf parameter 10
# [2026-04-21 16:36:29][INFO] Building KDTree structure with leaf parameter 10
# [2026-04-21 16:37:04][INFO] Building KDTree structure with leaf parameter 10
# Before coreg — median of M3C2 distances STABLE: 0.000 m  std of M3C2 distances STABLE: 0.000 m
# After  coreg — median of M3C2 distances STABLE: 0.000 m  std of M3C2 distances STABLE: 0.000 m
# Trafo saved to /home/asus/software/CNTP_hackathon/contributors/umayr/output/dem_dir/trafo_Reference_UAV_TLC.txt
# Saved co-registered cloud to /home/asus/software/CNTP_hackathon/contributors/umayr/output/coreg_PC_dir/Reference_UAV_TLC_coreg_TL.las
# Processing TL
# [2026-04-21 16:39:34][INFO] Building KDTree structure with leaf parameter 10
# ...
